# %%
import os
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import zipfile
#with zipfile.ZipFile("/content/drive/MyDrive/data/xdzlyx.com.zip", 'r') as zip_ref:
    #zip_ref.extractall("/content/drive/MyDrive/data")

# %%
file_en = open("/content/drive/MyDrive/data/en/abst_0.txt", "r", encoding = "utf-8")
file_zh = open("/content/drive/MyDrive/data/zh/abst_0.txt", "r", encoding = "utf-8")

# %%
en = file_en.read()
zh = file_zh.read()

# %%
from nltk.tokenize import sent_tokenize
import re
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
en_norm = re.sub(r'(?<=[.,])(?=[A-Z])', r' ', en)
en_norm
a = sent_tokenize(en_norm)
print(len(a), "\n" ,a)# Была идея разбивать длинные строки на предложения, но количество предложений в соответствующих сегментах разное.
# В итоге я от нее отказалась, в архиве есть довольно много коротких файлов с отдельными словами.
# Out:
# 8
#  ['Objective：To investigate the biological functions of A549 cell line by up-regulating CCL7 and explore the role of CCL7 in lung cancer metastasis.', 'Methods：A549 cell line was infected by CCL7 overexpressing lentiviral vector.', 'MTT，scratch test and Transwell cell invasion assay were performed.', 'Results：MTT assay showed that CCL7 overexpression promoted proliferation of A549 cells(P<0.01).', 'Scratch experiments showed that CCL7 can promote the migration of A549 cells(P<0.01).', 'At the same time，Transwell chamber invasion experiments confirmed that A549 cells with overexpression of CCL7 had stronger invasive ability(P<0.05).', 'Conclusion：The high expression of CCL7 can promote the proliferation，migration and invasion of lung cancer cells.', 'Further research on CCL7 may provide new directions for basic research，diagnosis and treatment of lung cancer.']

# %%
b = zh_norm = re.split(r"。", zh)
print(len(b), "\n" ,b)# Была идея разбивать длинные строки на предложения, но количество предложений в соответствующих сегментах разное.
# В итоге я от нее отказалась, в архиве есть довольно много коротких файлов с отдельными словами.
# Out:
# 7
#  ['目的：通过上调CCL7的表达，观察其对肺癌细胞A549增殖、迁移及侵袭等生物学功能的影响，探讨CCL7在肺癌转移中发挥的作用', '方法：慢病毒包装CCL7过表达载体感染A549细胞系，分别进行MTT、划痕实验和Transwell小室细胞侵袭实验', '结果：MTT实验显示CCL7过表达促进了A549细胞增殖(P<0.01)', '划痕实验表明CCL7过表达可以促进A549细胞迁移（P<0.01）', '同时Transwell小室侵袭实验证实过表达CCL7的A549细胞具有更强的侵袭能力（P<0.05）', '结论：CCL7的过表达可以促进肺癌细胞系A549的增殖、迁移和侵袭，对CCL7的进一步研究可以为肺癌基础研究及诊断治疗提供新的方向', '']

# %%
#import yaml
#test = (json.dumps({"zh": zh , "en": en}, sort_keys=True))
#test
#json.loads(test)
#y = yaml.safe_load(test)
#y 
#Пробовала наладить кодировку, нашла способ легче

# %%
json.dumps({"translation": {"zh": zh , "en": en}}, sort_keys=True, ensure_ascii=False, skipkeys = True)
# Out:
# '{"translation": {"en": "Objective：To investigate the biological functions of A549 cell line by up-regulating CCL7 and explore the role of CCL7 in lung cancer metastasis.Methods：A549 cell line was infected by CCL7 overexpressing lentiviral vector.MTT，scratch test and Transwell cell invasion assay were performed.Results：MTT assay showed that CCL7 overexpression promoted proliferation of A549 cells(P<0.01).Scratch experiments showed that CCL7 can promote the migration of A549 cells(P<0.01).At the same time，Transwell chamber invasion experiments confirmed that A549 cells with overexpression of CCL7 had stronger invasive ability(P<0.05).Conclusion：The high expression of CCL7 can promote the proliferation，migration and invasion of lung cancer cells.Further research on CCL7 may provide new directions for basic research，diagnosis and treatment of lung cancer.", "zh": "目的：通过上调CCL7的表达，观察其对肺癌细胞A549增殖、迁移及侵袭等生物学功能的影响，探讨CCL7在肺癌转移中发挥的作用。方法：慢病毒包装CCL7过表达载体感染A549细胞系，分别进行MTT、划痕实验和Transwell小室细胞侵袭实验。结果：
# ...

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
values_en = []
for file in os.listdir("/content/drive/MyDrive/data/en/"):
  f = open(file, "r", encoding = "utf-8")
  values_en.append(f.read())
  print(values_en)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-c831ea84fb46> in <module>()
#       1 values_en = []
#       2 for file in os.listdir("/content/drive/MyDrive/data/en/"):
# ----> 3   f = open(file, "r", encoding = "utf-8")
#       4   values_en.append(f.read())
#       5   print(values_en)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'key_1221.txt'

# %%
values_en = []
for filename in os.listdir("/content/drive/MyDrive/data/en/"):
    try:
      with open(filename, "r", encoding = "utf-8") as f:
       values_en.append(f.read())
    except FileNotFoundError:
      print("Oops")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# ...

# %%
! ls /content/drive/MyDrive/data/en
# Out:
# abst_0.txt     abst_5626.txt  head_2580.txt  head_7202.txt  key_4049.txt
# abst_1000.txt  abst_5627.txt  head_2581.txt  head_7203.txt  key_404.txt
# abst_1001.txt  abst_5628.txt  head_2582.txt  head_7204.txt  key_4050.txt
# abst_1002.txt  abst_5629.txt  head_2583.txt  head_7205.txt  key_4051.txt
# abst_1003.txt  abst_562.txt   head_2584.txt  head_7206.txt  key_4052.txt
# abst_1004.txt  abst_5630.txt  head_2585.txt  head_7207.txt  key_4053.txt
# abst_1005.txt  abst_5631.txt  head_2586.txt  head_7208.txt  key_4054.txt
# abst_1006.txt  abst_5632.txt  head_2587.txt  head_7209.txt  key_4055.txt
# abst_1007.txt  abst_5633.txt  head_2588.txt  head_720.txt   key_4056.txt
# abst_1008.txt  abst_5634.txt  head_2589.txt  head_7210.txt  key_4057.txt
# abst_1009.txt  abst_5635.txt  head_258.txt   head_7211.txt  key_4058.txt
# abst_100.txt   abst_5636.txt  head_2590.txt  head_7212.txt  key_4059.txt
# abst_1010.txt  abst_5637.txt  head_2591.txt  head_7213.txt  key_405.txt
# ...

# %%
values_en = []
for filename in os.listdir("/content/drive/MyDrive/data/en"):
  with open(filename, "r", encoding='utf-8') as f:
        vales_en.append(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-c213202a1009> in <module>()
#       1 values_en = []
#       2 for filename in os.listdir("/content/drive/MyDrive/data/en"):
# ----> 3   with open(filename, "r", encoding='utf-8') as f:
#       4         vales_en.append(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'key_1221.txt'

# %%
# !unzip -qq '/content/drive/MyDrive/data/xdzlyx.com.zip'

# %%
# !ls
# Out:
# drive  en  sample_data	zh

# %%
list_en = []
for filename in os.listdir("/content/en"):
  if filename.endswith('txt'):
     with open(filename, "r") as f:
        list_en.append(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-4398e12cb386> in <module>()
#       2 for filename in os.listdir("/content/en"):
#       3   if filename.endswith('txt'):
# ----> 4      with open(filename, "r") as f:
#       5         list_en.append(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'key_4621.txt'

# %%
os.getcwd()
# Out:
# '/content'
